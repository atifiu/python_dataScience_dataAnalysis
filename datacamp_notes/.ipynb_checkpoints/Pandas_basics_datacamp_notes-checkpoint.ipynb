# %%
# !pip install jupyter_contrib_nbextensions
# Out:
# Collecting jupyter_contrib_nbextensions
#   Downloading jupyter_contrib_nbextensions-0.7.0.tar.gz (23.5 MB)
# Requirement already satisfied: ipython_genutils in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Collecting jupyter_contrib_core>=0.3.3
#   Downloading jupyter_contrib_core-0.4.2.tar.gz (17 kB)
# Requirement already satisfied: jupyter_core in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter_contrib_nbextensions) (4.10.0)
# Collecting jupyter_highlight_selected_word>=0.1.1
#   Using cached jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting jupyter_nbextensions_configurator>=0.4.0
#   Downloading jupyter_nbextensions_configurator-0.6.1.tar.gz (481 kB)
# Requirement already satisfied: nbconvert>=6.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter_contrib_nbextensions) (6.5.0)
# Requirement already satisfied: notebook>=6.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter_contrib_nbextensions) (6.4.12)
# Requirement already satisfied: tornado in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter_contrib_nbextensions) (6.1)
# Requirement already satisfied: traitlets>=4.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter_contrib_nbextensions) (5.3.0)
# Requirement already satisfied: lxml in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter_contrib_nbextensions) (4.9.1)
# Requirement already satisfied: setuptools in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (61.2.0)
# Requirement already satisfied: pyyaml in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0)
# Requirement already satisfied: packaging in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (21.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.6.4)
# Requirement already satisfied: tinycss2 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.12.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: jinja2>=3.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.11.1)
# Requirement already satisfied: defusedxml in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: nbformat>=5.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.4.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: bleach in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (304)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (7.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.5)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (23.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.6.0)
# Requirement already satisfied: fastjsonschema in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.15.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (21.4.0)
# Requirement already satisfied: argon2-cffi in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.15.0)
# Requirement already satisfied: prometheus-client in c:\users\atif\appdata\roaming\python\python39\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: ipykernel in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (6.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from terminado>=0.8.3->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.3)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (8.4.0)
# Requirement already satisfied: psutil in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: stack-data in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.3.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.29)
# Requirement already satisfied: backcall in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: decorator in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: colorama in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.4.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from packaging->nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.9)
# Requirement already satisfied: asttokens in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: executing in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Building wheels for collected packages: jupyter-contrib-nbextensions, jupyter-contrib-core, jupyter-nbextensions-configurator
#   Building wheel for jupyter-contrib-nbextensions (setup.py): started
#   Building wheel for jupyter-contrib-nbextensions (setup.py): finished with status 'done'
#   Created wheel for jupyter-contrib-nbextensions: filename=jupyter_contrib_nbextensions-0.7.0-py2.py3-none-any.whl size=23428786 sha256=c4d0206f5177c57355a92f597fcf37447c7e7741af82b3ec871ab45acc8405a7
#   Stored in directory: c:\users\atif\appdata\local\pip\cache\wheels\e7\99\91\7f24a075786a6760f3ac32ab5fa92e1d1a90e0d2cd8958adfd
#   Building wheel for jupyter-contrib-core (setup.py): started
#   Building wheel for jupyter-contrib-core (setup.py): finished with status 'done'
#   Created wheel for jupyter-contrib-core: filename=jupyter_contrib_core-0.4.2-py2.py3-none-any.whl size=17484 sha256=bd4d87ebc4c79bf878534e645789d70665795bf200aef9ce69739a479fb057ee
#   Stored in directory: c:\users\atif\appdata\local\pip\cache\wheels\57\9f\80\32c07b8a950a45f6cf8cd5980c22a27ce514c27b795250e497
#   Building wheel for jupyter-nbextensions-configurator (setup.py): started
#   Building wheel for jupyter-nbextensions-configurator (setup.py): finished with status 'error'
#   Running setup.py clean for jupyter-nbextensions-configurator
# Successfully built jupyter-contrib-nbextensions jupyter-contrib-core
# Failed to build jupyter-nbextensions-configurator
# Installing collected packages: jupyter-contrib-core, jupyter-nbextensions-configurator, jupyter-highlight-selected-word, jupyter-contrib-nbextensions
#     Running setup.py install for jupyter-nbextensions-configurator: started
#     Running setup.py install for jupyter-nbextensions-configurator: finished with status 'done'
# Successfully installed jupyter-contrib-core-0.4.2 jupyter-contrib-nbextensions-0.7.0 jupyter-highlight-selected-word-0.2.0 jupyter-nbextensions-configurator-0.6.1
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Atif\anaconda3\envs\mynewenv\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Atif\\AppData\\Local\\Temp\\pip-install-eyjb1ga7\\jupyter-nbextensions-configurator_9480e83caec34d6ba391b7c14c3d268e\\setup.py'"'"'; __file__='"'"'C:\\Users\\Atif\\AppData\\Local\\Temp\\pip-install-eyjb1ga7\\jupyter-nbextensions-configurator_9480e83caec34d6ba391b7c14c3d268e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Atif\AppData\Local\Temp\pip-wheel-zx7ss2wk'
#        cwd: C:\Users\Atif\AppData\Local\Temp\pip-install-eyjb1ga7\jupyter-nbextensions-configurator_9480e83caec34d6ba391b7c14c3d268e\
#   Complete output (95 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib
#   creating build\lib\jupyter_nbextensions_configurator
#   copying src\jupyter_nbextensions_configurator\application.py -> build\lib\jupyter_nbextensions_configurator
#   copying src\jupyter_nbextensions_configurator\__init__.py -> build\lib\jupyter_nbextensions_configurator
#   running egg_info
#   writing src\jupyter_nbextensions_configurator.egg-info\PKG-INFO
#   writing dependency_links to src\jupyter_nbextensions_configurator.egg-info\dependency_links.txt
#   writing entry points to src\jupyter_nbextensions_configurator.egg-info\entry_points.txt
#   writing requirements to src\jupyter_nbextensions_configurator.egg-info\requires.txt
#   writing top-level names to src\jupyter_nbextensions_configurator.egg-info\top_level.txt
#   reading manifest file 'src\jupyter_nbextensions_configurator.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no previously-included files found matching '.bumpversion.cfg'
#   warning: no previously-included files found matching '.travis.yml'
#   warning: no previously-included files found matching 'appveyor.yml'
#   warning: no previously-included files found matching 'codecov.yml'
#   no previously-included directories found matching 'conda.recipe'
#   warning: no previously-included files matching '*~' found anywhere in distribution
#   warning: no previously-included files matching '__pycache__' found anywhere in distribution
#   warning: no previously-included files matching '*.py[cod]' found anywhere in distribution
#   warning: no previously-included files matching '.git' found anywhere in distribution
#   warning: no previously-included files matching '.ipynb_checkpoints' found anywhere in distribution
#   adding license file 'LICENSE.txt'
#   writing manifest file 'src\jupyter_nbextensions_configurator.egg-info\SOURCES.txt'
#   creating build\lib\jupyter_nbextensions_configurator\static
#   creating build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\icon.png -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\kse_components.js -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\main.css -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\main.js -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\quickhelp_shim.js -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\readme.md -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   creating build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu\config_menu.yaml -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu\icon.png -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu\main.js -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu
#   creating build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\render
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\render\render.js -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\render
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\render\rendermd.css -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\render
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\render\video_play.svg -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\render
#   creating build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab\icon.png -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab\main.js -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab\readme.md -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab
#   copying src\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab\tree_tab.yaml -> build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab
#   creating build\lib\jupyter_nbextensions_configurator\templates
#   copying src\jupyter_nbextensions_configurator\templates\nbextensions_configurator.html -> build\lib\jupyter_nbextensions_configurator\templates
#   copying src\jupyter_nbextensions_configurator\templates\rendermd.html -> build\lib\jupyter_nbextensions_configurator\templates
#   C:\Users\Atif\anaconda3\envs\mynewenv\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   installing to build\bdist.win-amd64\wheel
#   running install
#   running install_lib
#   creating build\bdist.win-amd64
#   creating build\bdist.win-amd64\wheel
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator
#   copying build\lib\jupyter_nbextensions_configurator\application.py -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator\static
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu\config_menu.yaml -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu\icon.png -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu\main.js -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator\config_menu
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\icon.png -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\kse_components.js -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\main.css -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\main.js -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\quickhelp_shim.js -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\readme.md -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator\static\nbextensions_configurator\render
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\render\render.js -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator\render
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\render\rendermd.css -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator\render
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\render\video_play.svg -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator\render
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab\icon.png -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab\main.js -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab\readme.md -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab
#   copying build\lib\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab\tree_tab.yaml -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\static\nbextensions_configurator\tree_tab
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator\templates
#   copying build\lib\jupyter_nbextensions_configurator\templates\nbextensions_configurator.html -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\templates
#   copying build\lib\jupyter_nbextensions_configurator\templates\rendermd.html -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator\templates
#   copying build\lib\jupyter_nbextensions_configurator\__init__.py -> build\bdist.win-amd64\wheel\.\jupyter_nbextensions_configurator
#   running install_data
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator-0.6.1.data
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator-0.6.1.data\data
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator-0.6.1.data\data\etc
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator-0.6.1.data\data\etc\jupyter
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator-0.6.1.data\data\etc\jupyter\nbconfig
#   creating build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator-0.6.1.data\data\etc\jupyter\nbconfig\notebook.d
#   copying jupyter-config\nbconfig\notebook.d\jupyter_nbextensions_configurator.json -> build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator-0.6.1.data\data\etc\jupyter\nbconfig\notebook.d
#   error: could not create 'build\bdist.win-amd64\wheel\jupyter_nbextensions_configurator-0.6.1.data\data\etc\jupyter\nbconfig\notebook.d\jupyter_nbextensions_configurator.json': No such file or directory
#   ----------------------------------------
#   ERROR: Failed building wheel for jupyter-nbextensions-configurator
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
#   DEPRECATION: jupyter-nbextensions-configurator was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. You can find discussion regarding this at https://github.com/pypa/pip/issues/8368.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)

# %%
#!pip install modin[ray] --user
# Out:
# Requirement already satisfied: modin[ray] in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (0.15.2)
# Requirement already satisfied: pandas==1.4.3 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from modin[ray]) (1.4.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from modin[ray]) (1.23.0)
# Requirement already satisfied: packaging in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from modin[ray]) (21.3)
# Requirement already satisfied: fsspec in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from modin[ray]) (2022.8.2)
# Requirement already satisfied: psutil in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from modin[ray]) (5.9.1)
# Requirement already satisfied: pyarrow>=4.0.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from modin[ray]) (6.0.1)
# Collecting redis<4.0.0,>=3.5.0
#   Using cached redis-3.5.3-py2.py3-none-any.whl (72 kB)
# Requirement already satisfied: ray[default]<1.13.0,>=1.4.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from modin[ray]) (1.12.1)
# Requirement already satisfied: protobuf<4.0.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from modin[ray]) (3.20.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from pandas==1.4.3->modin[ray]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from pandas==1.4.3->modin[ray]) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from python-dateutil>=2.8.1->pandas==1.4.3->modin[ray]) (1.16.0)
# Requirement already satisfied: requests in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (2.28.0)
# Requirement already satisfied: pyyaml in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (6.0)
# Requirement already satisfied: frozenlist in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.3.1)
# Requirement already satisfied: filelock in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (3.8.0)
# Requirement already satisfied: attrs in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (21.4.0)
# Requirement already satisfied: click>=7.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (8.0.4)
# Requirement already satisfied: aiosignal in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.2.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.0.4)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.43.0)
# Requirement already satisfied: jsonschema in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (4.6.0)
# Requirement already satisfied: virtualenv in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (20.16.4)
# Collecting py-spy>=0.2.0
#   Using cached py_spy-0.3.14-py2.py3-none-win_amd64.whl (1.4 MB)
# Collecting aiohttp-cors
#   Using cached aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting opencensus
#   Using cached opencensus-0.11.0-py2.py3-none-any.whl (128 kB)
# Collecting gpustat>=1.0.0b1
#   Using cached gpustat-1.0.0-py3-none-any.whl
# Requirement already satisfied: aiohttp>=3.7 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (3.8.3)
# Collecting prometheus-client<0.14.0,>=0.7.1
#   Using cached prometheus_client-0.13.1-py3-none-any.whl (57 kB)
# Requirement already satisfied: smart-open in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (6.3.0)
# Collecting colorful
#   Using cached colorful-0.5.5-py2.py3-none-any.whl (201 kB)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from aiohttp>=3.7->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.8.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from aiohttp>=3.7->ray[default]<1.13.0,>=1.4.0->modin[ray]) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from aiohttp>=3.7->ray[default]<1.13.0,>=1.4.0->modin[ray]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from aiohttp>=3.7->ray[default]<1.13.0,>=1.4.0->modin[ray]) (4.0.2)
# Requirement already satisfied: colorama in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from click>=7.0->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.4.5)
# Requirement already satisfied: nvidia-ml-py<=11.495.46,>=11.450.129 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from gpustat>=1.0.0b1->ray[default]<1.13.0,>=1.4.0->modin[ray]) (11.495.46)
# Requirement already satisfied: blessed>=1.17.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from gpustat>=1.0.0b1->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.19.1)
# Requirement already satisfied: jinxed>=1.1.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.2.0)
# Requirement already satisfied: wcwidth>=0.1.4 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.2.5)
# Requirement already satisfied: ansicon in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jinxed>=1.1.0->blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.89.0)
# Requirement already satisfied: idna>=2.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from yarl<2.0,>=1.0->aiohttp>=3.7->ray[default]<1.13.0,>=1.4.0->modin[ray]) (3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from jsonschema->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.18.1)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (2.11.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.1.3)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (2.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.57.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from requests->ray[default]<1.13.0,>=1.4.0->modin[ray]) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from requests->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.26.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from packaging->modin[ray]) (3.0.9)
# Requirement already satisfied: distlib<1,>=0.3.5 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from virtualenv->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.3.6)
# Requirement already satisfied: platformdirs<3,>=2.4 in c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages (from virtualenv->ray[default]<1.13.0,>=1.4.0->modin[ray]) (2.5.2)
# Installing collected packages: py-spy, prometheus-client, opencensus, gpustat, colorful, aiohttp-cors, redis
# Successfully installed aiohttp-cors-0.7.0 colorful-0.5.5 gpustat-1.0.0 opencensus-0.11.0 prometheus-client-0.13.1 py-spy-0.3.14 redis-3.5.3
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
#   WARNING: The script gpustat.exe is installed in 'C:\Users\Atif\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atif\anaconda3\envs\mynewenv\lib\site-packages)

# %%
import os
import ray
ray.init()
os.environ["MODIN_ENGINE"] = "ray"  # Modin will use Ray
import modin.pandas as pd
df = pd.read_csv(r"data/homelessness.csv")
# Out:
# 2023-01-03 14:24:35,899	INFO services.py:1456 -- View the Ray dashboard at http://127.0.0.1:8265

# %% [markdown]
# #### info() method displays column datatypes

# %%
df.info()
# Out:
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  --------------  --------------  -----
#  0   Unnamed: 0      51 non-null     int64
#  1   region          51 non-null     object
#  2   state           51 non-null     object
#  3   individuals     51 non-null     float64
#  4   family_members  51 non-null     float64
#  5   state_pop       51 non-null     int64
# dtypes: int64(2), object(2), float64(2)
# memory usage: 2.5 KB
# UserWarning: Distributing <class 'int'> object. This may take some time.

# %% [markdown]
# #### shape attribute gives size of df as rows, columns

# %%
df.shape
# Out:
# (51, 6)
